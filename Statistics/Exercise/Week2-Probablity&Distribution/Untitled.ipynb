# %%
import numpy as np
#import matplot.lib as plt
import pandas as pd

# %%
df = pd.read_csv("tennis.csv")
df.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2019-M020     Brisbane    Hard        NaN             A      20181231
# 1  2019-M020     Brisbane    Hard        NaN             A      20181231
# 2  2019-M020     Brisbane    Hard        NaN             A      20181231
# 3  2019-M020     Brisbane    Hard        NaN             A      20181231
# 4  2019-M020     Brisbane    Hard        NaN             A      20181231
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        243     106034          NaN          NaN  ...    37.0     28.0
# 1        244     117360          NaN          NaN  ...    65.0     49.0
# 2        245     106423          NaN          NaN  ...    44.0     31.0
# 3        246     106426          3.0          NaN  ...    33.0     28.0
# 4        247     200175          7.0          NaN  ...    21.0     12.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1536 entries, 0 to 1535
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tourney_id          1536 non-null   object
#  1   tourney_name        1536 non-null   object
#  2   surface             1536 non-null   object
#  3   draw_size           0 non-null      float64
#  4   tourney_level       1536 non-null   object
#  5   tourney_date        1536 non-null   int64
#  6   match_num           1536 non-null   int64
#  7   winner_id           1536 non-null   int64
#  8   winner_seed         677 non-null    float64
#  9   winner_entry        251 non-null    object
#  10  winner_name         1536 non-null   object
#  11  winner_hand         1536 non-null   object
#  12  winner_ht           301 non-null    float64
#  13  winner_ioc          1536 non-null   object
#  14  winner_age          1536 non-null   float64
# ...
